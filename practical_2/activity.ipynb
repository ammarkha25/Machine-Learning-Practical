# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
dataset = pd.read_csv("Data - Data.csv")
df = pd.DataFrame(dataset)
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
print("\nMissing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())
df = df.drop_duplicates()

encoder = LabelEncoder()
df["Purchased"] = encoder.fit_transform(df["Purchased"])

scaler = StandardScaler()
df[["Age", "Salary"]] = scaler.fit_transform(df[["Age", "Salary"]])

print("\nPreprocessed Dataset\n")
print(df)
# Out:
# Preprocessed Dataset
#
#    Country           Age        Salary  Purchased
# 0   France  7.588744e-01  7.494733e-01          0
# 1    Spain -1.711504e+00 -1.438178e+00          1
# 2  Germany -1.275555e+00 -8.912655e-01          0
# 3    Spain -1.130238e-01 -2.532004e-01          0
# 4  Germany  1.776089e-01  2.357833e-16          1
# 5   France -5.489729e-01 -5.266569e-01          1
# 6    Spain  1.110223e-16 -1.073570e+00          0
# 7   France  1.340140e+00  1.387538e+00          1
# 8  Germany  1.630773e+00  1.752147e+00          0
# 9   France -2.583402e-01  2.937125e-01          1

# %%
df.to_csv("cleaned_dataset1.csv", index=False)

print("\nDataset saved as cleaned_dataset1.csv")
# Out:
# Dataset saved as cleaned_dataset1.csv
