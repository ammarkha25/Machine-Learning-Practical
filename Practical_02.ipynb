# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

data = {
    "Name": ["Amit", "Priya", "Rahul", "Priya", "Karan"],
    "Age": [21, 22, None, 22, 20],
    "Gender": ["Male", "Female", "Male", "Female", "Male"],
    "Marks": [85, 90, 78, 90, None]
}

df = pd.DataFrame(data)

print("Original Dataset\n")
print(df)

print("\nMissing Values")
print(df.isnull().sum())

df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

df = df.drop_duplicates()

encoder = LabelEncoder()

df["Gender"] = encoder.fit_transform(df["Gender"])

scaler = StandardScaler()

df[["Age", "Marks"]] = scaler.fit_transform(df[["Age", "Marks"]])

print("\nPreprocessed Dataset\n")
print(df)

df.to_csv("cleaned_dataset.csv", index=False)

print("\nDataset saved as cleaned_dataset.csv")
# Out:
# Original Dataset
#
#     Name   Age  Gender  Marks
# 0   Amit  21.0    Male   85.0
# 1  Priya  22.0  Female   90.0
# 2  Rahul   NaN    Male   78.0
# 3  Priya  22.0  Female   90.0
# 4  Karan  20.0    Male    NaN
#
# Missing Values
# Name      0
# Age       1
# Gender    0
# Marks     1
# dtype: int64
#
# Preprocessed Dataset
#
#     Name       Age  Gender     Marks
# 0   Amit -0.087370       1  0.072571
# 1  Priya  1.310556       0  1.233699
# 2  Rahul  0.262111       1 -1.553010
# 4  Karan -1.485297       1  0.246740
#
# Dataset saved as cleaned_dataset.csv
